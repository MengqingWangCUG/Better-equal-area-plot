# %%
import testeq

# 运行所有测试
testeq.run_all_tests()
# Out:
# Starting equal-area projection plot tests...
# ...
# Test 1: Basic equal-area projection plot
# Test 1: Passed
# ------------------------------
# Test 2: Equal-area projection plot with confidence ellipse
# c:\Users\wangm\Desktop\huizong\code\Ppython\Better EAplot\testeq.py:37: UltraPlotWarning: 'subplot_kw' is not necessary in ultraplot. Pass the parameters as keyword arguments instead.
#   fig, ax = upt.subplots(figsize=(8, 8), subplot_kw=dict(projection='polar'))
# c:\Users\wangm\Desktop\huizong\code\Ppython\Better EAplot\testeq.py:53: UltraPlotWarning: 'subplot_kw' is not necessary in ultraplot. Pass the parameters as keyword arguments instead.
#   fig, ax = upt.subplots(figsize=(8, 8), subplot_kw=dict(projection='polar'))
# Test 2: Passed
# ------------------------------
# Test 3: Fisher statistics analysis
# ...
